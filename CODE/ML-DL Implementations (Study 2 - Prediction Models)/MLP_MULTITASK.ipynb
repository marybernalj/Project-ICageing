# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# MLP

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, Concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam # Add this line to import the Adam
# Split data into training and test sets
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import mean_absolute_error # Import the mean_absolute_error function


# %load_ext tensorboard

import os
log_dir = os.path.join("logs") # Puedes cambiar "logs" por el nombre que quieras
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

from tensorflow.keras.callbacks import TensorBoard

tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)


# Cargar los datos (suponiendo que están en un archivo CSV)
data = pd.read_csv('/content/drive/My Drive/PREDICTIVE MODEL IC/DATA/DATOS_OBSERVACION_VAR_NOTNULL2010-2022_TRANSFORM.csv')

#ARREGLO PARA CALC_IMC NULL
data['CALC_IMC'] = data.groupby('ID')['CALC_IMC'].transform(lambda x: round(x.fillna(x.mean()), 0))
#eliminar filas con datos nulos en IMC
data = data.dropna(subset=['CALC_IMC'])

# Contar registros por ID, ignorando los NaN
#conteo_registros_por_persona = data.groupby('ID')['ID'].count()

# Personas con exactamente 4 registros (sin considerar NaN)
#personas_con_4_registros = conteo_registros_por_persona[conteo_registros_por_persona == 4]
#print(personas_con_4_registros)

data.to_csv('/content/drive/My Drive/PREDICTIVE MODEL IC/DATA/DATOS_OBSERVACION_VAR_NOTNULL2010-2022_TRANSFORM_1.csv', index=False)
data = pd.read_csv('/content/drive/My Drive/PREDICTIVE MODEL IC/DATA/DATOS_OBSERVACION_VAR_NOTNULL2010-2022_TRANSFORM_1.csv')

# Normalize numerical variables
columns_to_scale = ['LOCOMOTION','SENSORY','VITALITY','PSICHOLOGICAL','COGNITION','CIGARRETTES','DRINK','CALC_IMC', 'AGE']
scaler = MinMaxScaler(feature_range=(0, 1))
#scaler = StandardScaler()
scaled_data = scaler.fit_transform(data[columns_to_scale])
#data[columns_to_scale] = scaled_data
data.loc[:, columns_to_scale] = scaled_data

# Convert categorical variables to one-hot encoding
# Crear un objeto OneHotEncoder
columns_to_transform = ['SEX','ALONE','PHYSICAL_ACTIVITY']
encoder = OneHotEncoder(sparse_output=False)
encoded_data = encoder.fit_transform(data[columns_to_transform])
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(columns_to_transform))
data = pd.concat([data, encoded_df], axis=1)

#data = data.drop(columns=['SEX','ALONE','PHYSICAL_ACTIVITY'])

# Agrupar por ID y ordenar por 'Evaluación'
#data_grouped = data.sort_values('evaluacion').groupby('ID')

#data = data.drop(columns=['ID','año','evaluación'])

#data.head()
#print(data.columns)

data.to_csv('/content/drive/My Drive/PREDICTIVE MODEL IC/DATA/DATOS_OBSERVACION_VAR_NOTNULL2010-2022_TRANSFORM_ENCODED.csv', index=False)

# Definimos las columnas de las variables a predecir (target)
target_cols = ['LOCOMOTION','SENSORY','VITALITY','PSICHOLOGICAL','COGNITION']

# Prepare sequences and targets
def create_dataset(data, look_back=3):
  sequences = []
  targets = []
  locomotions = []
  sensories = []
  vitalities = []
  psichologicals = []
  cognitions = []
  auxiliares = []
  for person_id in data['ID'].unique():
    person_data = data[data['ID'] == person_id].sort_values('evaluacion')

     # Get the indices of the relevant columns
    relevant_columns = ['LOCOMOTION', 'SENSORY', 'VITALITY','PSICHOLOGICAL', 'COGNITION',
                        'ALONE_PARTNERED', 'ALONE_UNCOUPLED',
                        'PHYSICAL_ACTIVITY_SEDENTARY', 'PHYSICAL_ACTIVITY_MILD','PHYSICAL_ACTIVITY_MODERATE', 'PHYSICAL_ACTIVITY_VIGOROUS',
                        'CIGARRETTES','DRINK', 'CALC_IMC']
    auxiliar_columns = ['AGE','SEX_FEMALE', 'SEX_MALE']
     # Select the relevant columns first
    person_data_values = person_data[relevant_columns].values
    person_data_auxiliar = person_data[auxiliar_columns].values

    # Create sequences and targets
    if len(person_data_values) < look_back + 1:
        continue
    sequence = person_data_values[:look_back, :]
    target = person_data_values[look_back, data.columns.get_indexer(target_cols)]
    locomotion = person_data_values[look_back, 0]
    sensory = person_data_values[look_back, 1]
    vitality = person_data_values[look_back, 2]
    psichological = person_data_values[look_back, 3]
    cognition = person_data_values[look_back, 4]
    auxiliar = person_data_auxiliar[look_back, :]
    sequences.append(sequence)
    targets.append(target)
    locomotions.append(locomotion)
    sensories.append(sensory)
    vitalities.append(vitality)
    psichologicals.append(psichological)
    cognitions.append(cognition)
    auxiliares.append(auxiliar)
  return np.array(sequences), np.array(targets), np.array(locomotions), np.array(sensories), np.array(vitalities), np.array(psichologicals), np.array(cognitions), np.array(auxiliares)

# Create sequences and targets
look_back = 3
sequences, targets, locomotions, sensories, vitalities, psichologicals, cognitions, auxiliares = create_dataset(data, look_back)

pd.DataFrame(sequences[0]).head()
sequences.shape
sequences.shape[2]

sequences.shape[2]
#pd.DataFrame(targets[0]).head()

auxiliares.shape
auxiliares.shape[1]

targets.shape

# TRAINNING AND TEST

# Assuming 'sequences' and 'auxiliares' are your input features,
# and 'locomotions', 'sensories', etc. are your targets
# Split into 80% training and 20% testing
(
    sequences_train,
    sequences_test,
    auxiliares_train,
    auxiliares_test,
    locomotions_train,
    locomotions_test,
    sensories_train,
    sensories_test,
    vitalities_train,
    vitalities_test,
    psichologicals_train,
    psichologicals_test,
    cognitions_train,
    cognitions_test,
) = train_test_split(
    sequences,
    auxiliares,
    locomotions,
    sensories,
    vitalities,
    psichologicals,
    cognitions,
    test_size=0.2,
    random_state=42,  # Optional: for reproducibility
)


# Define input shapes
sequential_input_shape = (sequences.shape[1], sequences.shape[2])  # Adjust num_sequential_features
auxiliary_input_shape = (auxiliares.shape[1],)  # Adjust num_auxiliary_features

# Create the model
def create_model_mlp():
     # Input layers
    sequential_input = Input(shape=(sequences.shape[1] * sequences.shape[2],), name='sequential_input') # Flatten sequential input
    auxiliary_input = Input(shape=(auxiliares.shape[1],), name='auxiliary_input')

     # Process sequential input with MLP
    sequential_mlp = Dense(64, activation='relu')(sequential_input) # Adjust units and activation as needed
    sequential_mlp = Dropout(0.2)(sequential_mlp)
    sequential_mlp = Dense(32, activation='relu')(sequential_mlp)  # Adjust units and activation as needed
    sequential_mlp = Dropout(0.2)(sequential_mlp)

    # Concatenate sequential and auxiliary inputs
    concatenated_input = Concatenate()([sequential_mlp, auxiliary_input])

    # Shared MLP layers
    shared_mlp = Dense(32, activation='relu')(concatenated_input) # Adjust units and activation as needed
    shared_mlp = Dropout(0.2)(shared_mlp)
    shared_mlp = Dense(16, activation='relu')(shared_mlp) # Adjust units and activation as needed
    shared_mlp = Dropout(0.2)(shared_mlp)

    # Output layers for each task
    l_output = Dense(1, activation='linear', name='l_output')(shared_mlp)
    s_output = Dense(1, activation='linear', name='s_output')(shared_mlp)
    v_output = Dense(1, activation='linear', name='v_output')(shared_mlp)
    p_output = Dense(1, activation='linear', name='p_output')(shared_mlp)
    c_output = Dense(1, activation='linear', name='c_output')(shared_mlp)

    # Create the model
    model = Model(inputs=[sequential_input, auxiliary_input], outputs=[l_output, s_output, v_output, p_output, c_output ])
    return model

# Compile the model
model = create_model_mlp()
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss=['mse', 'mse', 'mse', 'mse', 'mse'],
              metrics=[['mse','mae'], ['mse','mae'], ['mse','mae'], ['mse','mae'], ['mse','mae']])  # Adjust loss weights if needed

# Resumen del modelo
model.summary()
keras.utils.plot_model(model, 'modelo.png', show_shapes=True)

# Flatten the training and testing data before fitting/evaluating:
sequences_train_flattened = sequences_train.reshape(sequences_train.shape[0], -1)
sequences_test_flattened = sequences_test.reshape(sequences_test.shape[0], -1)

# Train the model
model.fit(x=[sequences_train_flattened, auxiliares_train],
          y=[locomotions_train, sensories_train, vitalities_train, psichologicals_train, cognitions_train],
          epochs=50, batch_size=256, verbose=1, callbacks=[tensorboard_callback])

# Evaluate the model
results = model.evaluate([sequences_test_flattened, auxiliares_test],
                        {'l_output': locomotions_test, 's_output': sensories_test, 'v_output': vitalities_test, 'p_output': psichologicals_test, 'c_output': cognitions_test})


# Extract loss and metrics (order should match compilation and evaluation metrics)
loss = results[0]  # Total loss
l_loss = results[1]  # Loss for 'l_output'
s_loss = results[2]  # Loss for 's_output'
v_loss = results[3]  # Loss for 'v_output'
p_loss = results[4]  # Loss for 'p_output'
c_loss = results[5]  # Loss for 'c_output'

# Assuming correct order, retrieve MAE values
l_mae = results[6]  # MAE for 'l_output'
s_mae = results[7]  # MAE for 's_output'
v_mae = results[8]  # MAE for 'v_output'
p_mae = results[9]  # MAE for 'p_output'
c_mae = results[10]  # MAE for 'c_output'


print(f"\nResultados de la evaluación ORIGINAL:\n"
      f"Pérdida total: {loss:.4f}\n"
      f"Pérdida para l (Regresión): {l_loss:.4f}\n"
      f"Pérdida para s (Regresión): {s_loss:.4f}\n"
      f"Pérdida para v (Regresión): {v_loss:.4f}\n"
      f"Pérdida para p (Regresión): {p_loss:.4f}\n"
      f"Pérdida para c (Regresión): {c_loss:.4f}\n"
      f"MAE para l (Regresión): {l_mae:.4f}\n"
     f"MAE para s (Regresión): {s_mae:.4f}\n"
    f"MAE para v (Regresión): {v_mae:.4f}\n"
     f"MAE para p (Regresión): {p_mae:.4f}\n"
     f"MAE para c (Regresión): {c_mae:.4f}"
      )


# Función para calcular MAE con intervalo de confianza usando Bootstrap (CÓDIGO NUEVO)
def calcular_mae_intervalo_confianza(
    sequences_train, auxiliares_train, locomotions_train, sensories_train, vitalities_train, psichologicals_train, cognitions_train,
    sequences_test, auxiliares_test, locomotions_test, sensories_test, vitalities_test, psichologicals_test, cognitions_test,
    num_ejecuciones=1000
):
    l_maes = []
    s_maes = []
    v_maes = []
    p_maes = []
    c_maes = []

    for _ in range(num_ejecuciones):
        indices_bootstrap = resample(np.arange(len(sequences_test)), replace=True, n_samples=len(sequences_test))

        sequences_bootstrap = sequences_test[indices_bootstrap]
        auxiliares_bootstrap = auxiliares_test[indices_bootstrap]
        locomotions_bootstrap = locomotions_test[indices_bootstrap]
        sensories_bootstrap = sensories_test[indices_bootstrap]
        vitalities_bootstrap = vitalities_test[indices_bootstrap]
        psichologicals_bootstrap = psichologicals_test[indices_bootstrap]
        cognitions_bootstrap = cognitions_test[indices_bootstrap]

        # 2. Evaluate the model on the bootstrap sample (no training in each iteration)
        #predictions = model.predict([sequences_bootstrap, auxiliares_bootstrap])

        # Before evaluating the model, flatten the bootstrap sample
        sequences_bootstrap_flattened = sequences_bootstrap.reshape(sequences_bootstrap.shape[0], -1)

         # Evaluate the model on the bootstrap sample
        results1 = model.evaluate(
        [sequences_bootstrap_flattened, auxiliares_bootstrap],
        [locomotions_bootstrap, sensories_bootstrap, vitalities_bootstrap, psichologicals_bootstrap, cognitions_bootstrap],
        verbose=0  # Set verbose to 0 to suppress output during evaluation
        )

        # Extract MAE values from the results
        l_mae = results1[6]  # MAE for 'l_output' (assuming the correct index)
        s_mae = results1[7]  # MAE for 's_output'
        v_mae = results1[8]  # MAE for 'v_output'
        p_mae = results1[9]  # MAE for 'p_output'
        c_mae = results1[10]  # MAE for 'c_output'

        # Calcula el MAE para cada variable objetivo usando las predicciones (CÓDIGO NUEVO)
       # l_mae = mean_absolute_error(locomotions_bootstrap, predictions[0])
        #s_mae = mean_absolute_error(sensories_bootstrap, predictions[1])
        #v_mae = mean_absolute_error(vitalities_bootstrap, predictions[2])
        #p_mae = mean_absolute_error(psichologicals_bootstrap, predictions[3])
        #c_mae = mean_absolute_error(cognitions_bootstrap, predictions[4])

        l_maes.append(l_mae)
        s_maes.append(s_mae)
        v_maes.append(v_mae)
        p_maes.append(p_mae)
        c_maes.append(c_mae)

    # Función para calcular estadísticas e intervalos de confianza (CÓDIGO NUEVO)
    def calculate_ci(maes):
        mae_promedio = np.mean(maes)
        desviacion_estandar = np.std(maes)
        valor_critico = 1.96  # Para un intervalo de confianza del 95%
        margen_de_error = valor_critico * (desviacion_estandar / np.sqrt(num_ejecuciones))
        limite_inferior = mae_promedio - margen_de_error
        limite_superior = mae_promedio + margen_de_error
        return mae_promedio, (limite_inferior, limite_superior)

    l_results = calculate_ci(l_maes)
    s_results = calculate_ci(s_maes)
    v_results = calculate_ci(v_maes)
    p_results = calculate_ci(p_maes)
    c_results = calculate_ci(c_maes)

    return {
        'l': l_results,
        's': s_results,
        'v': v_results,
        'p': p_results,
        'c': c_results,
    }

# Calcula intervalo de confianza con Bootstrap (CÓDIGO NUEVO)
resultados_bootstrap = calcular_mae_intervalo_confianza(
    sequences_train, auxiliares_train, locomotions_train, sensories_train, vitalities_train, psichologicals_train, cognitions_train,
    sequences_test, auxiliares_test, locomotions_test, sensories_test, vitalities_test, psichologicals_test, cognitions_test,
    num_ejecuciones=1000
)

# Imprime los resultados del Bootstrap (CÓDIGO NUEVO)
for target, (mae_promedio, intervalo_confianza) in resultados_bootstrap.items():
    print(f"MAE para {target} (Regresión): {mae_promedio:.4f} (IC 95%: {intervalo_confianza})")
# Out:
# <ipython-input-2-1ef5d0805e75>:54: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1.         0.81818182 0.90909091 ... 0.72727273 0.54545455 0.81818182]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:, columns_to_scale] = scaled_data
# <ipython-input-2-1ef5d0805e75>:54: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.61428571 0.65714286 0.71428571 ... 0.32857143 0.38571429 0.44285714]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:, columns_to_scale] = scaled_data
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ sequential_input          │ (None, 42)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │          2,752 │ sequential_input[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 64)             │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 32)             │          2,080 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 32)             │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ auxiliary_input           │ (None, 3)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 35)             │              0 │ dropout_1[0][0],       │
# │                           │                        │                │ auxiliary_input[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          1,152 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 32)             │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 16)             │            528 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 16)             │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ l_output (Dense)          │ (None, 1)              │             17 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ s_output (Dense)          │ (None, 1)              │             17 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ v_output (Dense)          │ (None, 1)              │             17 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ p_output (Dense)          │ (None, 1)              │             17 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ c_output (Dense)          │ (None, 1)              │             17 │ dropout_3[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 6,597 (25.77 KB)
#  Trainable params: 6,597 (25.77 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - c_output_loss: 1.1846 - c_output_mae: 0.9786 - c_output_mse: 1.1926 - l_output_loss: 0.6016 - l_output_mae: 0.6808 - l_output_mse: 0.6033 - loss: 3.2052 - p_output_loss: 0.3236 - p_output_mae: 0.4603 - p_output_mse: 0.3243 - s_output_loss: 0.5218 - s_output_mae: 0.6357 - s_output_mse: 0.5225 - v_output_loss: 0.5607 - v_output_mae: 0.6438 - v_output_mse: 0.5624
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - c_output_loss: 0.3419 - c_output_mae: 0.4827 - c_output_mse: 0.3431 - l_output_loss: 0.3874 - l_output_mae: 0.5372 - l_output_mse: 0.3872 - loss: 1.6846 - p_output_loss: 0.3092 - p_output_mae: 0.4460 - p_output_mse: 0.3103 - s_output_loss: 0.3700 - s_output_mae: 0.5195 - s_output_mse: 0.3715 - v_output_loss: 0.2717 - v_output_mae: 0.4315 - v_output_mse: 0.2725
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - c_output_loss: 0.2607 - c_output_mae: 0.4127 - c_output_mse: 0.2617 - l_output_loss: 0.2788 - l_output_mae: 0.4414 - l_output_mse: 0.2798 - loss: 1.2674 - p_output_loss: 0.2222 - p_output_mae: 0.3865 - p_output_mse: 0.2227 - s_output_loss: 0.2539 - s_output_mae: 0.4191 - s_output_mse: 0.2554 - v_output_loss: 0.2463 - v_output_mae: 0.4118 - v_output_mse: 0.2478
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - c_output_loss: 0.2652 - c_output_mae: 0.4038 - c_output_mse: 0.2657 - l_output_loss: 0.2542 - l_output_mae: 0.4082 - l_output_mse: 0.2541 - loss: 1.0887 - p_output_loss: 0.2083 - p_output_mae: 0.3687 - p_output_mse: 0.2078 - s_output_loss: 0.1688 - s_output_mae: 0.3338 - s_output_mse: 0.1690 - v_output_loss: 0.1921 - v_output_mae: 0.3556 - v_output_mse: 0.1921
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.2702 - c_output_mae: 0.4092 - c_output_mse: 0.2710 - l_output_loss: 0.2380 - l_output_mae: 0.3966 - l_output_mse: 0.2390 - loss: 1.0150 - p_output_loss: 0.1833 - p_output_mae: 0.3522 - p_output_mse: 0.1835 - s_output_loss: 0.1558 - s_output_mae: 0.3197 - s_output_mse: 0.1564 - v_output_loss: 0.1648 - v_output_mae: 0.3307 - v_output_mse: 0.1650
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - c_output_loss: 0.2308 - c_output_mae: 0.3784 - c_output_mse: 0.2309 - l_output_loss: 0.2176 - l_output_mae: 0.3733 - l_output_mse: 0.2176 - loss: 0.9159 - p_output_loss: 0.1647 - p_output_mae: 0.3280 - p_output_mse: 0.1646 - s_output_loss: 0.1569 - s_output_mae: 0.3172 - s_output_mse: 0.1567 - v_output_loss: 0.1463 - v_output_mae: 0.3124 - v_output_mse: 0.1461
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - c_output_loss: 0.2093 - c_output_mae: 0.3619 - c_output_mse: 0.2092 - l_output_loss: 0.2015 - l_output_mae: 0.3634 - l_output_mse: 0.2016 - loss: 0.8314 - p_output_loss: 0.1544 - p_output_mae: 0.3164 - p_output_mse: 0.1546 - s_output_loss: 0.1348 - s_output_mae: 0.2952 - s_output_mse: 0.1355 - v_output_loss: 0.1303 - v_output_mae: 0.2935 - v_output_mse: 0.1304
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - c_output_loss: 0.1995 - c_output_mae: 0.3546 - c_output_mse: 0.2002 - l_output_loss: 0.1840 - l_output_mae: 0.3467 - l_output_mse: 0.1841 - loss: 0.7673 - p_output_loss: 0.1402 - p_output_mae: 0.2961 - p_output_mse: 0.1405 - s_output_loss: 0.1221 - s_output_mae: 0.2826 - s_output_mse: 0.1223 - v_output_loss: 0.1199 - v_output_mae: 0.2770 - v_output_mse: 0.1201
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - c_output_loss: 0.1818 - c_output_mae: 0.3331 - c_output_mse: 0.1822 - l_output_loss: 0.1739 - l_output_mae: 0.3334 - l_output_mse: 0.1740 - loss: 0.7118 - p_output_loss: 0.1316 - p_output_mae: 0.2926 - p_output_mse: 0.1323 - s_output_loss: 0.1162 - s_output_mae: 0.2753 - s_output_mse: 0.1160 - v_output_loss: 0.1071 - v_output_mae: 0.2647 - v_output_mse: 0.1073
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - c_output_loss: 0.1784 - c_output_mae: 0.3326 - c_output_mse: 0.1784 - l_output_loss: 0.1661 - l_output_mae: 0.3261 - l_output_mse: 0.1655 - loss: 0.6846 - p_output_loss: 0.1233 - p_output_mae: 0.2814 - p_output_mse: 0.1232 - s_output_loss: 0.1120 - s_output_mae: 0.2709 - s_output_mse: 0.1123 - v_output_loss: 0.1051 - v_output_mae: 0.2617 - v_output_mse: 0.1052
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - c_output_loss: 0.1729 - c_output_mae: 0.3299 - c_output_mse: 0.1730 - l_output_loss: 0.1564 - l_output_mae: 0.3145 - l_output_mse: 0.1568 - loss: 0.6367 - p_output_loss: 0.1141 - p_output_mae: 0.2692 - p_output_mse: 0.1142 - s_output_loss: 0.0988 - s_output_mae: 0.2515 - s_output_mse: 0.0990 - v_output_loss: 0.0936 - v_output_mae: 0.2445 - v_output_mse: 0.0936
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - c_output_loss: 0.1470 - c_output_mae: 0.3027 - c_output_mse: 0.1468 - l_output_loss: 0.1429 - l_output_mae: 0.2964 - l_output_mse: 0.1428 - loss: 0.5915 - p_output_loss: 0.1161 - p_output_mae: 0.2706 - p_output_mse: 0.1157 - s_output_loss: 0.0932 - s_output_mae: 0.2476 - s_output_mse: 0.0930 - v_output_loss: 0.0933 - v_output_mae: 0.2446 - v_output_mse: 0.0931
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - c_output_loss: 0.1414 - c_output_mae: 0.2989 - c_output_mse: 0.1416 - l_output_loss: 0.1290 - l_output_mae: 0.2824 - l_output_mse: 0.1291 - loss: 0.5621 - p_output_loss: 0.1117 - p_output_mae: 0.2595 - p_output_mse: 0.1114 - s_output_loss: 0.0892 - s_output_mae: 0.2384 - s_output_mse: 0.0891 - v_output_loss: 0.0909 - v_output_mae: 0.2394 - v_output_mse: 0.0910
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - c_output_loss: 0.1436 - c_output_mae: 0.3054 - c_output_mse: 0.1438 - l_output_loss: 0.1393 - l_output_mae: 0.2944 - l_output_mse: 0.1397 - loss: 0.5621 - p_output_loss: 0.1053 - p_output_mae: 0.2551 - p_output_mse: 0.1051 - s_output_loss: 0.0875 - s_output_mae: 0.2386 - s_output_mse: 0.0876 - v_output_loss: 0.0858 - v_output_mae: 0.2342 - v_output_mse: 0.0859
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - c_output_loss: 0.1290 - c_output_mae: 0.2862 - c_output_mse: 0.1294 - l_output_loss: 0.1178 - l_output_mae: 0.2720 - l_output_mse: 0.1180 - loss: 0.5268 - p_output_loss: 0.1077 - p_output_mae: 0.2571 - p_output_mse: 0.1080 - s_output_loss: 0.0876 - s_output_mae: 0.2360 - s_output_mse: 0.0875 - v_output_loss: 0.0838 - v_output_mae: 0.2321 - v_output_mse: 0.0840
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - c_output_loss: 0.1171 - c_output_mae: 0.2715 - c_output_mse: 0.1169 - l_output_loss: 0.1177 - l_output_mae: 0.2737 - l_output_mse: 0.1170 - loss: 0.4913 - p_output_loss: 0.0975 - p_output_mae: 0.2477 - p_output_mse: 0.0975 - s_output_loss: 0.0842 - s_output_mae: 0.2316 - s_output_mse: 0.0847 - v_output_loss: 0.0750 - v_output_mae: 0.2190 - v_output_mse: 0.0751
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - c_output_loss: 0.1173 - c_output_mae: 0.2708 - c_output_mse: 0.1172 - l_output_loss: 0.1194 - l_output_mae: 0.2693 - l_output_mse: 0.1193 - loss: 0.4937 - p_output_loss: 0.0950 - p_output_mae: 0.2403 - p_output_mse: 0.0950 - s_output_loss: 0.0853 - s_output_mae: 0.2328 - s_output_mse: 0.0855 - v_output_loss: 0.0769 - v_output_mae: 0.2200 - v_output_mse: 0.0768
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0973 - c_output_mae: 0.2504 - c_output_mse: 0.0977 - l_output_loss: 0.1087 - l_output_mae: 0.2579 - l_output_mse: 0.1088 - loss: 0.4436 - p_output_loss: 0.0880 - p_output_mae: 0.2334 - p_output_mse: 0.0882 - s_output_loss: 0.0787 - s_output_mae: 0.2243 - s_output_mse: 0.0785 - v_output_loss: 0.0702 - v_output_mae: 0.2122 - v_output_mse: 0.0704
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - c_output_loss: 0.1084 - c_output_mae: 0.2616 - c_output_mse: 0.1087 - l_output_loss: 0.1091 - l_output_mae: 0.2608 - l_output_mse: 0.1097 - loss: 0.4590 - p_output_loss: 0.0908 - p_output_mae: 0.2322 - p_output_mse: 0.0903 - s_output_loss: 0.0757 - s_output_mae: 0.2205 - s_output_mse: 0.0759 - v_output_loss: 0.0746 - v_output_mae: 0.2199 - v_output_mse: 0.0745
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - c_output_loss: 0.1001 - c_output_mae: 0.2512 - c_output_mse: 0.1006 - l_output_loss: 0.1052 - l_output_mae: 0.2529 - l_output_mse: 0.1055 - loss: 0.4389 - p_output_loss: 0.0931 - p_output_mae: 0.2415 - p_output_mse: 0.0931 - s_output_loss: 0.0683 - s_output_mae: 0.2092 - s_output_mse: 0.0685 - v_output_loss: 0.0710 - v_output_mae: 0.2155 - v_output_mse: 0.0713
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.0934 - c_output_mae: 0.2441 - c_output_mse: 0.0938 - l_output_loss: 0.1007 - l_output_mae: 0.2493 - l_output_mse: 0.1008 - loss: 0.4214 - p_output_loss: 0.0884 - p_output_mae: 0.2332 - p_output_mse: 0.0888 - s_output_loss: 0.0708 - s_output_mae: 0.2112 - s_output_mse: 0.0708 - v_output_loss: 0.0671 - v_output_mae: 0.2075 - v_output_mse: 0.0673
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0841 - c_output_mae: 0.2318 - c_output_mse: 0.0841 - l_output_loss: 0.1110 - l_output_mae: 0.2650 - l_output_mse: 0.1109 - loss: 0.4103 - p_output_loss: 0.0799 - p_output_mae: 0.2198 - p_output_mse: 0.0800 - s_output_loss: 0.0696 - s_output_mae: 0.2103 - s_output_mse: 0.0697 - v_output_loss: 0.0656 - v_output_mae: 0.2035 - v_output_mse: 0.0656
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.0879 - c_output_mae: 0.2359 - c_output_mse: 0.0881 - l_output_loss: 0.1058 - l_output_mae: 0.2577 - l_output_mse: 0.1056 - loss: 0.4059 - p_output_loss: 0.0834 - p_output_mae: 0.2225 - p_output_mse: 0.0834 - s_output_loss: 0.0634 - s_output_mae: 0.2010 - s_output_mse: 0.0629 - v_output_loss: 0.0659 - v_output_mae: 0.2058 - v_output_mse: 0.0660
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0782 - c_output_mae: 0.2220 - c_output_mse: 0.0784 - l_output_loss: 0.0960 - l_output_mae: 0.2453 - l_output_mse: 0.0961 - loss: 0.3802 - p_output_loss: 0.0812 - p_output_mae: 0.2211 - p_output_mse: 0.0812 - s_output_loss: 0.0640 - s_output_mae: 0.2046 - s_output_mse: 0.0642 - v_output_loss: 0.0608 - v_output_mae: 0.1937 - v_output_mse: 0.0604
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0733 - c_output_mae: 0.2166 - c_output_mse: 0.0735 - l_output_loss: 0.0953 - l_output_mae: 0.2421 - l_output_mse: 0.0952 - loss: 0.3634 - p_output_loss: 0.0767 - p_output_mae: 0.2154 - p_output_mse: 0.0768 - s_output_loss: 0.0609 - s_output_mae: 0.1950 - s_output_mse: 0.0608 - v_output_loss: 0.0572 - v_output_mae: 0.1877 - v_output_mse: 0.0570
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.0830 - c_output_mae: 0.2275 - c_output_mse: 0.0831 - l_output_loss: 0.0955 - l_output_mae: 0.2447 - l_output_mse: 0.0954 - loss: 0.3792 - p_output_loss: 0.0754 - p_output_mae: 0.2139 - p_output_mse: 0.0753 - s_output_loss: 0.0631 - s_output_mae: 0.2006 - s_output_mse: 0.0632 - v_output_loss: 0.0622 - v_output_mae: 0.1989 - v_output_mse: 0.0621
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0727 - c_output_mae: 0.2114 - c_output_mse: 0.0730 - l_output_loss: 0.0939 - l_output_mae: 0.2373 - l_output_mse: 0.0941 - loss: 0.3631 - p_output_loss: 0.0773 - p_output_mae: 0.2126 - p_output_mse: 0.0775 - s_output_loss: 0.0592 - s_output_mae: 0.1937 - s_output_mse: 0.0591 - v_output_loss: 0.0593 - v_output_mae: 0.1946 - v_output_mse: 0.0594
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - c_output_loss: 0.0689 - c_output_mae: 0.2081 - c_output_mse: 0.0694 - l_output_loss: 0.0917 - l_output_mae: 0.2315 - l_output_mse: 0.0912 - loss: 0.3455 - p_output_loss: 0.0725 - p_output_mae: 0.2060 - p_output_mse: 0.0722 - s_output_loss: 0.0584 - s_output_mae: 0.1948 - s_output_mse: 0.0581 - v_output_loss: 0.0547 - v_output_mae: 0.1864 - v_output_mse: 0.0546
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.0709 - c_output_mae: 0.2113 - c_output_mse: 0.0709 - l_output_loss: 0.0912 - l_output_mae: 0.2384 - l_output_mse: 0.0916 - loss: 0.3459 - p_output_loss: 0.0703 - p_output_mae: 0.2021 - p_output_mse: 0.0701 - s_output_loss: 0.0578 - s_output_mae: 0.1914 - s_output_mse: 0.0577 - v_output_loss: 0.0558 - v_output_mae: 0.1892 - v_output_mse: 0.0556
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - c_output_loss: 0.0672 - c_output_mae: 0.2059 - c_output_mse: 0.0672 - l_output_loss: 0.0910 - l_output_mae: 0.2373 - l_output_mse: 0.0910 - loss: 0.3369 - p_output_loss: 0.0694 - p_output_mae: 0.2007 - p_output_mse: 0.0693 - s_output_loss: 0.0562 - s_output_mae: 0.1905 - s_output_mse: 0.0562 - v_output_loss: 0.0532 - v_output_mae: 0.1833 - v_output_mse: 0.0532
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - c_output_loss: 0.0690 - c_output_mae: 0.2111 - c_output_mse: 0.0693 - l_output_loss: 0.0940 - l_output_mae: 0.2397 - l_output_mse: 0.0939 - loss: 0.3386 - p_output_loss: 0.0660 - p_output_mae: 0.1975 - p_output_mse: 0.0662 - s_output_loss: 0.0553 - s_output_mae: 0.1875 - s_output_mse: 0.0552 - v_output_loss: 0.0541 - v_output_mae: 0.1865 - v_output_mse: 0.0541
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - c_output_loss: 0.0631 - c_output_mae: 0.1985 - c_output_mse: 0.0629 - l_output_loss: 0.0890 - l_output_mae: 0.2330 - l_output_mse: 0.0891 - loss: 0.3345 - p_output_loss: 0.0701 - p_output_mae: 0.2016 - p_output_mse: 0.0702 - s_output_loss: 0.0582 - s_output_mae: 0.1928 - s_output_mse: 0.0582 - v_output_loss: 0.0541 - v_output_mae: 0.1862 - v_output_mse: 0.0540
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - c_output_loss: 0.0618 - c_output_mae: 0.1973 - c_output_mse: 0.0617 - l_output_loss: 0.0903 - l_output_mae: 0.2358 - l_output_mse: 0.0901 - loss: 0.3227 - p_output_loss: 0.0648 - p_output_mae: 0.1928 - p_output_mse: 0.0650 - s_output_loss: 0.0548 - s_output_mae: 0.1858 - s_output_mse: 0.0549 - v_output_loss: 0.0510 - v_output_mae: 0.1809 - v_output_mse: 0.0510
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0630 - c_output_mae: 0.1997 - c_output_mse: 0.0632 - l_output_loss: 0.0892 - l_output_mae: 0.2348 - l_output_mse: 0.0891 - loss: 0.3209 - p_output_loss: 0.0664 - p_output_mae: 0.1943 - p_output_mse: 0.0666 - s_output_loss: 0.0502 - s_output_mae: 0.1782 - s_output_mse: 0.0498 - v_output_loss: 0.0521 - v_output_mae: 0.1848 - v_output_mse: 0.0522
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.0597 - c_output_mae: 0.1915 - c_output_mse: 0.0597 - l_output_loss: 0.0867 - l_output_mae: 0.2321 - l_output_mse: 0.0864 - loss: 0.3099 - p_output_loss: 0.0630 - p_output_mae: 0.1912 - p_output_mse: 0.0631 - s_output_loss: 0.0512 - s_output_mae: 0.1795 - s_output_mse: 0.0512 - v_output_loss: 0.0495 - v_output_mae: 0.1780 - v_output_mse: 0.0494
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - c_output_loss: 0.0596 - c_output_mae: 0.1906 - c_output_mse: 0.0595 - l_output_loss: 0.0844 - l_output_mae: 0.2270 - l_output_mse: 0.0844 - loss: 0.3122 - p_output_loss: 0.0650 - p_output_mae: 0.1904 - p_output_mse: 0.0652 - s_output_loss: 0.0530 - s_output_mae: 0.1844 - s_output_mse: 0.0531 - v_output_loss: 0.0497 - v_output_mae: 0.1772 - v_output_mse: 0.0499
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0600 - c_output_mae: 0.1918 - c_output_mse: 0.0599 - l_output_loss: 0.0815 - l_output_mae: 0.2248 - l_output_mse: 0.0814 - loss: 0.3029 - p_output_loss: 0.0633 - p_output_mae: 0.1860 - p_output_mse: 0.0633 - s_output_loss: 0.0511 - s_output_mae: 0.1789 - s_output_mse: 0.0511 - v_output_loss: 0.0471 - v_output_mae: 0.1727 - v_output_mse: 0.0472
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - c_output_loss: 0.0579 - c_output_mae: 0.1885 - c_output_mse: 0.0579 - l_output_loss: 0.0847 - l_output_mae: 0.2285 - l_output_mse: 0.0850 - loss: 0.3008 - p_output_loss: 0.0590 - p_output_mae: 0.1831 - p_output_mse: 0.0591 - s_output_loss: 0.0499 - s_output_mae: 0.1808 - s_output_mse: 0.0501 - v_output_loss: 0.0485 - v_output_mae: 0.1748 - v_output_mse: 0.0487
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - c_output_loss: 0.0547 - c_output_mae: 0.1833 - c_output_mse: 0.0546 - l_output_loss: 0.0801 - l_output_mae: 0.2209 - l_output_mse: 0.0801 - loss: 0.2853 - p_output_loss: 0.0559 - p_output_mae: 0.1805 - p_output_mse: 0.0561 - s_output_loss: 0.0479 - s_output_mae: 0.1735 - s_output_mse: 0.0480 - v_output_loss: 0.0464 - v_output_mae: 0.1735 - v_output_mse: 0.0466
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.0517 - c_output_mae: 0.1782 - c_output_mse: 0.0517 - l_output_loss: 0.0819 - l_output_mae: 0.2202 - l_output_mse: 0.0820 - loss: 0.2848 - p_output_loss: 0.0566 - p_output_mae: 0.1769 - p_output_mse: 0.0568 - s_output_loss: 0.0489 - s_output_mae: 0.1784 - s_output_mse: 0.0489 - v_output_loss: 0.0452 - v_output_mae: 0.1698 - v_output_mse: 0.0453
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - c_output_loss: 0.0540 - c_output_mae: 0.1843 - c_output_mse: 0.0538 - l_output_loss: 0.0778 - l_output_mae: 0.2146 - l_output_mse: 0.0779 - loss: 0.2809 - p_output_loss: 0.0588 - p_output_mae: 0.1800 - p_output_mse: 0.0588 - s_output_loss: 0.0463 - s_output_mae: 0.1709 - s_output_mse: 0.0464 - v_output_loss: 0.0440 - v_output_mae: 0.1666 - v_output_mse: 0.0441
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - c_output_loss: 0.0518 - c_output_mae: 0.1802 - c_output_mse: 0.0518 - l_output_loss: 0.0798 - l_output_mae: 0.2233 - l_output_mse: 0.0797 - loss: 0.2794 - p_output_loss: 0.0551 - p_output_mae: 0.1754 - p_output_mse: 0.0553 - s_output_loss: 0.0465 - s_output_mae: 0.1729 - s_output_mse: 0.0465 - v_output_loss: 0.0460 - v_output_mae: 0.1699 - v_output_mse: 0.0460
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - c_output_loss: 0.0493 - c_output_mae: 0.1753 - c_output_mse: 0.0493 - l_output_loss: 0.0800 - l_output_mae: 0.2188 - l_output_mse: 0.0795 - loss: 0.2739 - p_output_loss: 0.0527 - p_output_mae: 0.1707 - p_output_mse: 0.0526 - s_output_loss: 0.0458 - s_output_mae: 0.1708 - s_output_mse: 0.0458 - v_output_loss: 0.0469 - v_output_mae: 0.1726 - v_output_mse: 0.0468
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - c_output_loss: 0.0507 - c_output_mae: 0.1765 - c_output_mse: 0.0507 - l_output_loss: 0.0755 - l_output_mae: 0.2133 - l_output_mse: 0.0753 - loss: 0.2713 - p_output_loss: 0.0527 - p_output_mae: 0.1699 - p_output_mse: 0.0531 - s_output_loss: 0.0463 - s_output_mae: 0.1721 - s_output_mse: 0.0465 - v_output_loss: 0.0459 - v_output_mae: 0.1713 - v_output_mse: 0.0458
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - c_output_loss: 0.0505 - c_output_mae: 0.1769 - c_output_mse: 0.0507 - l_output_loss: 0.0825 - l_output_mae: 0.2271 - l_output_mse: 0.0826 - loss: 0.2731 - p_output_loss: 0.0507 - p_output_mae: 0.1665 - p_output_mse: 0.0509 - s_output_loss: 0.0454 - s_output_mae: 0.1692 - s_output_mse: 0.0455 - v_output_loss: 0.0433 - v_output_mae: 0.1659 - v_output_mse: 0.0435
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - c_output_loss: 0.0532 - c_output_mae: 0.1819 - c_output_mse: 0.0531 - l_output_loss: 0.0798 - l_output_mae: 0.2180 - l_output_mse: 0.0796 - loss: 0.2748 - p_output_loss: 0.0525 - p_output_mae: 0.1704 - p_output_mse: 0.0527 - s_output_loss: 0.0467 - s_output_mae: 0.1711 - s_output_mse: 0.0468 - v_output_loss: 0.0427 - v_output_mae: 0.1650 - v_output_mse: 0.0426
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - c_output_loss: 0.0484 - c_output_mae: 0.1727 - c_output_mse: 0.0483 - l_output_loss: 0.0804 - l_output_mae: 0.2218 - l_output_mse: 0.0804 - loss: 0.2757 - p_output_loss: 0.0566 - p_output_mae: 0.1773 - p_output_mse: 0.0568 - s_output_loss: 0.0445 - s_output_mae: 0.1681 - s_output_mse: 0.0444 - v_output_loss: 0.0457 - v_output_mae: 0.1705 - v_output_mse: 0.0458
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - c_output_loss: 0.0466 - c_output_mae: 0.1710 - c_output_mse: 0.0465 - l_output_loss: 0.0791 - l_output_mae: 0.2176 - l_output_mse: 0.0792 - loss: 0.2654 - p_output_loss: 0.0520 - p_output_mae: 0.1695 - p_output_mse: 0.0519 - s_output_loss: 0.0445 - s_output_mae: 0.1676 - s_output_mse: 0.0446 - v_output_loss: 0.0433 - v_output_mae: 0.1658 - v_output_mse: 0.0431
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - c_output_loss: 0.0496 - c_output_mae: 0.1740 - c_output_mse: 0.0496 - l_output_loss: 0.0787 - l_output_mae: 0.2192 - l_output_mse: 0.0790 - loss: 0.2622 - p_output_loss: 0.0493 - p_output_mae: 0.1658 - p_output_mse: 0.0493 - s_output_loss: 0.0424 - s_output_mae: 0.1642 - s_output_mse: 0.0425 - v_output_loss: 0.0418 - v_output_mae: 0.1629 - v_output_mse: 0.0419
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - c_output_loss: 0.0450 - c_output_mae: 0.1649 - c_output_mse: 0.0451 - l_output_loss: 0.0725 - l_output_mae: 0.2060 - l_output_mse: 0.0726 - loss: 0.2536 - p_output_loss: 0.0498 - p_output_mae: 0.1674 - p_output_mse: 0.0500 - s_output_loss: 0.0450 - s_output_mae: 0.1696 - s_output_mse: 0.0450 - v_output_loss: 0.0410 - v_output_mae: 0.1614 - v_output_mse: 0.0409
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - c_output_loss: 0.0191 - c_output_mae: 0.1121 - c_output_mse: 0.0191 - l_output_loss: 0.0442 - l_output_mae: 0.1837 - l_output_mse: 0.0441 - loss: 0.1492 - p_output_loss: 0.0335 - p_output_mae: 0.1255 - p_output_mse: 0.0335 - s_output_loss: 0.0281 - s_output_mae: 0.1318 - s_output_mse: 0.0281 - v_output_loss: 0.0244 - v_output_mae: 0.1320 - v_output_mse: 0.0244
#
# Resultados de la evaluación ORIGINAL:
# Pérdida total: 0.1550
# Pérdida para l (Regresión): 0.0497
# Pérdida para s (Regresión): 0.0287
# Pérdida para v (Regresión): 0.0251
# Pérdida para p (Regresión): 0.0340
# Pérdida para c (Regresión): 0.0185
# MAE para l (Regresión): 0.1091
# MAE para s (Regresión): 0.0188
# MAE para v (Regresión): 0.1921
# MAE para p (Regresión): 0.0490
# MAE para c (Regresión): 0.1267
# MAE para l (Regresión): 0.1092 (IC 95%: (0.10897676701178431, 0.10942421115110039))
# MAE para s (Regresión): 0.0188 (IC 95%: (0.01871488273342896, 0.018875739760568257))
# MAE para v (Regresión): 0.1922 (IC 95%: (0.19194738941061998, 0.19251694913041092))
# MAE para p (Regresión): 0.0491 (IC 95%: (0.04889635774730197, 0.04930031288178213))
# MAE para c (Regresión): 0.1269 (IC 95%: (0.1265801620034883, 0.12730028483286407))
